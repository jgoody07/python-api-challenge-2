# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="

url = base_url + weather_api_key

city_data = []
print("Beginning Data Retrieval")
print("-----------------------------")

record_count = 1
set_count = 1

for index, city in enumerate(cities):
    if (index%50==0 and index>=50):
        record_count = 1 
        set_count = set_count + 1
        
    query_url = url + "&q=" + city
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city)) 
    record_count = record_count + 1
    
    try: 
        city_weather = requests.get(query_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except:
        print("City not found. Skipping...")
        pass 
        
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lethem
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | manta
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | yulara
# Processing Record 7 of Set 1 | nhamunda
# Processing Record 8 of Set 1 | staro nagoricane
# City not found. Skipping...
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | fenoarivo atsinanana
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | zamora
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | ginir
# Processing Record 20 of Set 1 | roald
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | ust-tsilma
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 1 | bastia
# Processing Record 27 of Set 1 | ugoofaaru
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | kruisfontein
# Processing Record 30 of Set 1 | riyadh
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | mahebourg
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | stornoway
# Processing Record 38 of Set 1 | aktau
# Processing Record 39 of Set 1 | xiongshi
# City not found. Skipping...
# Processing Record 40 of Set 1 | rocha
# Processing Record 41 of Set 1 | nicoya
# Processing Record 42 of Set 1 | forbes
# Processing Record 43 of Set 1 | teahupoo
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | guerrero negro
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | clyde river
# Processing Record 50 of Set 1 | vallenar
# Processing Record 1 of Set 2 | gracanica
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | botwood
# Processing Record 4 of Set 2 | havelock
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | kutum
# Processing Record 7 of Set 2 | agadez
# Processing Record 8 of Set 2 | sitka
# Processing Record 9 of Set 2 | leningradskiy
# Processing Record 10 of Set 2 | bengkulu
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | abu kamal
# Processing Record 15 of Set 2 | polyarnyy
# Processing Record 16 of Set 2 | waingapu
# Processing Record 17 of Set 2 | lubango
# Processing Record 18 of Set 2 | naryan-mar
# Processing Record 19 of Set 2 | olinda
# Processing Record 20 of Set 2 | port hardy
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | jiayuguan
# Processing Record 23 of Set 2 | cherskiy
# Processing Record 24 of Set 2 | gari
# Processing Record 25 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 2 | pevek
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | vestbygda
# City not found. Skipping...
# Processing Record 29 of Set 2 | savinka
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | antofagasta
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | hamilton
# Processing Record 34 of Set 2 | hasaki
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | vuktyl
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | waddan
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | kanigoro
# Processing Record 43 of Set 2 | fergus falls
# Processing Record 44 of Set 2 | touros
# Processing Record 45 of Set 2 | languyan
# Processing Record 46 of Set 2 | cidreira
# Processing Record 47 of Set 2 | catia la mar
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | kropotkin
# Processing Record 2 of Set 3 | olavarria
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | altay
# Processing Record 5 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 6 of Set 3 | athabasca
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | joaquim nabuco
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | natitingou
# Processing Record 12 of Set 3 | westport
# Processing Record 13 of Set 3 | metu
# Processing Record 14 of Set 3 | lompoc
# Processing Record 15 of Set 3 | tuktoyaktuk
# Processing Record 16 of Set 3 | tommot
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | makakilo city
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | talara
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | rio gallegos
# Processing Record 25 of Set 3 | kokopo
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | srednekolymsk
# Processing Record 28 of Set 3 | plettenberg bay
# Processing Record 29 of Set 3 | husavik
# Processing Record 30 of Set 3 | atuona
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | havoysund
# Processing Record 33 of Set 3 | albany
# Processing Record 34 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 3 | thinadhoo
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | okhotsk
# Processing Record 38 of Set 3 | kavieng
# Processing Record 39 of Set 3 | sambava
# Processing Record 40 of Set 3 | nevelsk
# Processing Record 41 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 3 | cockburn town
# Processing Record 43 of Set 3 | labuhan
# Processing Record 44 of Set 3 | new norfolk
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | lucapa
# Processing Record 47 of Set 3 | fougamou
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | mangan
# Processing Record 50 of Set 3 | dawson creek
# Processing Record 1 of Set 4 | beatrice
# Processing Record 2 of Set 4 | thiers
# Processing Record 3 of Set 4 | naze
# Processing Record 4 of Set 4 | aykhal
# Processing Record 5 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 4 | vestmanna
# Processing Record 7 of Set 4 | qandala
# Processing Record 8 of Set 4 | codrington
# Processing Record 9 of Set 4 | coquimbo
# Processing Record 10 of Set 4 | lixourion
# Processing Record 11 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 4 | myski
# Processing Record 15 of Set 4 | nanortalik
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | tecoanapa
# Processing Record 18 of Set 4 | san policarpo
# Processing Record 19 of Set 4 | vicosa
# Processing Record 20 of Set 4 | thompson
# Processing Record 21 of Set 4 | kahului
# Processing Record 22 of Set 4 | ballina
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 25 of Set 4 | baykit
# Processing Record 26 of Set 4 | klyuchi
# Processing Record 27 of Set 4 | itoman
# Processing Record 28 of Set 4 | tessalit
# Processing Record 29 of Set 4 | ilulissat
# Processing Record 30 of Set 4 | saint anthony
# Processing Record 31 of Set 4 | mudyuga
# City not found. Skipping...
# Processing Record 32 of Set 4 | pacific grove
# Processing Record 33 of Set 4 | navrongo
# Processing Record 34 of Set 4 | banda aceh
# Processing Record 35 of Set 4 | bakchar
# Processing Record 36 of Set 4 | conceicao do araguaia
# Processing Record 37 of Set 4 | bluff
# Processing Record 38 of Set 4 | barstow
# Processing Record 39 of Set 4 | fairfield
# Processing Record 40 of Set 4 | longyearbyen
# Processing Record 41 of Set 4 | hambantota
# Processing Record 42 of Set 4 | leo
# Processing Record 43 of Set 4 | rawson
# Processing Record 44 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 4 | paungde
# Processing Record 46 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 47 of Set 4 | bay roberts
# Processing Record 48 of Set 4 | pacifica
# Processing Record 49 of Set 4 | huesca
# Processing Record 50 of Set 4 | noumea
# Processing Record 1 of Set 5 | maraa
# Processing Record 2 of Set 5 | port blair
# Processing Record 3 of Set 5 | warrington
# Processing Record 4 of Set 5 | erzin
# Processing Record 5 of Set 5 | menongue
# Processing Record 6 of Set 5 | mogzon
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | muzhi
# Processing Record 9 of Set 5 | iqaluit
# Processing Record 10 of Set 5 | port keats
# Processing Record 11 of Set 5 | maicao
# Processing Record 12 of Set 5 | jiangkou
# Processing Record 13 of Set 5 | adzope
# Processing Record 14 of Set 5 | ostrovnoy
# Processing Record 15 of Set 5 | santa rosa
# Processing Record 16 of Set 5 | zabol
# Processing Record 17 of Set 5 | waipawa
# Processing Record 18 of Set 5 | san quintin
# Processing Record 19 of Set 5 | kapaa
# Processing Record 20 of Set 5 | le mars
# Processing Record 21 of Set 5 | maniitsoq
# Processing Record 22 of Set 5 | sao filipe
# Processing Record 23 of Set 5 | beypur
# City not found. Skipping...
# Processing Record 24 of Set 5 | adrar
# Processing Record 25 of Set 5 | faya
# Processing Record 26 of Set 5 | penzance
# Processing Record 27 of Set 5 | kembe
# Processing Record 28 of Set 5 | panlaitan
# Processing Record 29 of Set 5 | sur
# Processing Record 30 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 31 of Set 5 | salalah
# Processing Record 32 of Set 5 | ahipara
# Processing Record 33 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 5 | natchitoches
# Processing Record 36 of Set 5 | egvekinot
# Processing Record 37 of Set 5 | klaksvik
# Processing Record 38 of Set 5 | fernley
# Processing Record 39 of Set 5 | belen
# Processing Record 40 of Set 5 | san patricio
# Processing Record 41 of Set 5 | hami
# Processing Record 42 of Set 5 | orlik
# Processing Record 43 of Set 5 | kirakira
# Processing Record 44 of Set 5 | vila
# Processing Record 45 of Set 5 | valentin gomez farias
# Processing Record 46 of Set 5 | sweetwater
# Processing Record 47 of Set 5 | nushki
# Processing Record 48 of Set 5 | nizhniy kuranakh
# Processing Record 49 of Set 5 | barrow
# Processing Record 50 of Set 5 | klichka
# Processing Record 1 of Set 6 | namatanai
# Processing Record 2 of Set 6 | kavaratti
# Processing Record 3 of Set 6 | durango
# Processing Record 4 of Set 6 | poum
# Processing Record 5 of Set 6 | bandarbeyla
# Processing Record 6 of Set 6 | cayenne
# Processing Record 7 of Set 6 | rafraf
# Processing Record 8 of Set 6 | vila franca do campo
# Processing Record 9 of Set 6 | dubti
# Processing Record 10 of Set 6 | colesberg
# Processing Record 11 of Set 6 | fortuna
# Processing Record 12 of Set 6 | samarai
# Processing Record 13 of Set 6 | nemuro
# Processing Record 14 of Set 6 | dunkirk
# Processing Record 15 of Set 6 | akureyri
# Processing Record 16 of Set 6 | skibbereen
# Processing Record 17 of Set 6 | gines
# Processing Record 18 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 19 of Set 6 | tukrah
# Processing Record 20 of Set 6 | coihaique
# Processing Record 21 of Set 6 | silopi
# Processing Record 22 of Set 6 | bongandanga
# Processing Record 23 of Set 6 | tiksi
# Processing Record 24 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 6 | shingu
# Processing Record 26 of Set 6 | daxian
# City not found. Skipping...
# Processing Record 27 of Set 6 | salinas
# Processing Record 28 of Set 6 | bonthe
# Processing Record 29 of Set 6 | san cristobal
# Processing Record 30 of Set 6 | cuenca
# Processing Record 31 of Set 6 | belmonte
# Processing Record 32 of Set 6 | turbat
# Processing Record 33 of Set 6 | zlobin
# Processing Record 34 of Set 6 | dingle
# Processing Record 35 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 36 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 6 | jurmala
# Processing Record 38 of Set 6 | fairbanks
# Processing Record 39 of Set 6 | rudbar
# Processing Record 40 of Set 6 | atambua
# Processing Record 41 of Set 6 | gewane
# Processing Record 42 of Set 6 | labytnangi
# Processing Record 43 of Set 6 | srikakulam
# Processing Record 44 of Set 6 | tomatlan
# Processing Record 45 of Set 6 | chapleau
# Processing Record 46 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 6 | arman
# Processing Record 48 of Set 6 | camacha
# Processing Record 49 of Set 6 | kiunga
# Processing Record 50 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 1 of Set 7 | beringovskiy
# Processing Record 2 of Set 7 | darhan
# Processing Record 3 of Set 7 | iracoubo
# Processing Record 4 of Set 7 | ixtapa
# Processing Record 5 of Set 7 | karasjok
# Processing Record 6 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 7 | provideniya
# Processing Record 8 of Set 7 | beloha
# Processing Record 9 of Set 7 | yaan
# Processing Record 10 of Set 7 | port moresby
# Processing Record 11 of Set 7 | los llanos de aridane
# Processing Record 12 of Set 7 | launceston
# Processing Record 13 of Set 7 | nieuw amsterdam
# Processing Record 14 of Set 7 | severo-kurilsk
# Processing Record 15 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 7 | sargatskoye
# Processing Record 17 of Set 7 | north battleford
# Processing Record 18 of Set 7 | dubuque
# Processing Record 19 of Set 7 | san pedro
# Processing Record 20 of Set 7 | hudiksvall
# Processing Record 21 of Set 7 | kon tum
# Processing Record 22 of Set 7 | sulangan
# Processing Record 23 of Set 7 | ancud
# Processing Record 24 of Set 7 | paamiut
# Processing Record 25 of Set 7 | chuy
# Processing Record 26 of Set 7 | tilichiki
# Processing Record 27 of Set 7 | san vicente
# Processing Record 28 of Set 7 | saldanha
# Processing Record 29 of Set 7 | yar-sale
# Processing Record 30 of Set 7 | san ramon
# Processing Record 31 of Set 7 | trofors
# Processing Record 32 of Set 7 | pemangkat
# Processing Record 33 of Set 7 | eureka
# Processing Record 34 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 7 | boda
# Processing Record 36 of Set 7 | lagoa
# Processing Record 37 of Set 7 | englewood
# Processing Record 38 of Set 7 | redmond
# Processing Record 39 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 7 | hanna
# Processing Record 41 of Set 7 | enterprise
# Processing Record 42 of Set 7 | yushu
# Processing Record 43 of Set 7 | ketchikan
# Processing Record 44 of Set 7 | avera
# Processing Record 45 of Set 7 | linguere
# Processing Record 46 of Set 7 | kalabo
# Processing Record 47 of Set 7 | macia
# Processing Record 48 of Set 7 | tselinnoye
# Processing Record 49 of Set 7 | pochutla
# Processing Record 50 of Set 7 | minden
# Processing Record 1 of Set 8 | cap malheureux
# Processing Record 2 of Set 8 | prince rupert
# Processing Record 3 of Set 8 | balakhta
# Processing Record 4 of Set 8 | emba
# Processing Record 5 of Set 8 | nosy varika
# Processing Record 6 of Set 8 | katsuura
# Processing Record 7 of Set 8 | arraial do cabo
# Processing Record 8 of Set 8 | brigantine
# Processing Record 9 of Set 8 | geraldton
# Processing Record 10 of Set 8 | obihiro
# Processing Record 11 of Set 8 | harper
# Processing Record 12 of Set 8 | namibe
# Processing Record 13 of Set 8 | mezen
# Processing Record 14 of Set 8 | podgornoye
# Processing Record 15 of Set 8 | jaru
# Processing Record 16 of Set 8 | kamenka
# Processing Record 17 of Set 8 | shelburne
# Processing Record 18 of Set 8 | abalak
# Processing Record 19 of Set 8 | nome
# Processing Record 20 of Set 8 | puerto narino
# Processing Record 21 of Set 8 | lewiston
# Processing Record 22 of Set 8 | kaiwaka
# Processing Record 23 of Set 8 | kolpashevo
# Processing Record 24 of Set 8 | aswan
# Processing Record 25 of Set 8 | amla
# Processing Record 26 of Set 8 | nishihara
# Processing Record 27 of Set 8 | la serena
# Processing Record 28 of Set 8 | hualmay
# Processing Record 29 of Set 8 | oakham
# Processing Record 30 of Set 8 | hay river
# Processing Record 31 of Set 8 | anton lizardo
# Processing Record 32 of Set 8 | praia da vitoria
# Processing Record 33 of Set 8 | hargeysa
# Processing Record 34 of Set 8 | raudeberg
# Processing Record 35 of Set 8 | lavrentiya
# Processing Record 36 of Set 8 | apache junction
# Processing Record 37 of Set 8 | bilma
# Processing Record 38 of Set 8 | college
# Processing Record 39 of Set 8 | cabinda
# Processing Record 40 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 41 of Set 8 | felipe carrillo puerto
# Processing Record 42 of Set 8 | constitucion
# Processing Record 43 of Set 8 | kabanjahe
# Processing Record 44 of Set 8 | uusikaupunki
# Processing Record 45 of Set 8 | kununurra
# Processing Record 46 of Set 8 | san andres
# Processing Record 47 of Set 8 | laguna
# Processing Record 48 of Set 8 | ramnagar
# Processing Record 49 of Set 8 | wanaka
# Processing Record 50 of Set 8 | xam nua
# Processing Record 1 of Set 9 | yarada
# Processing Record 2 of Set 9 | mount isa
# Processing Record 3 of Set 9 | vila velha
# Processing Record 4 of Set 9 | les escoumins
# Processing Record 5 of Set 9 | broken hill
# Processing Record 6 of Set 9 | rabo de peixe
# Processing Record 7 of Set 9 | dakar
# Processing Record 8 of Set 9 | kalaleh
# Processing Record 9 of Set 9 | asau
# Processing Record 10 of Set 9 | sinop
# Processing Record 11 of Set 9 | matamoros
# Processing Record 12 of Set 9 | lexington
# Processing Record 13 of Set 9 | isangel
# Processing Record 14 of Set 9 | urbana
# Processing Record 15 of Set 9 | nyrob
# Processing Record 16 of Set 9 | port lincoln
# Processing Record 17 of Set 9 | bismil
# Processing Record 18 of Set 9 | dawei
# Processing Record 19 of Set 9 | nadym
# Processing Record 20 of Set 9 | maneadero
# Processing Record 21 of Set 9 | shimoda
# Processing Record 22 of Set 9 | goderich
# Processing Record 23 of Set 9 | kemijarvi
# Processing Record 24 of Set 9 | koster
# Processing Record 25 of Set 9 | udachnyy
# Processing Record 26 of Set 9 | mackay
# Processing Record 27 of Set 9 | ouallam
# Processing Record 28 of Set 9 | rab
# City not found. Skipping...
# Processing Record 29 of Set 9 | lima
# Processing Record 30 of Set 9 | ambon
# Processing Record 31 of Set 9 | ilheus
# Processing Record 32 of Set 9 | pangnirtung
# Processing Record 33 of Set 9 | meiganga
# Processing Record 34 of Set 9 | roches noires
# City not found. Skipping...
# Processing Record 35 of Set 9 | kloulklubed
# Processing Record 36 of Set 9 | sisophon
# Processing Record 37 of Set 9 | broome
# Processing Record 38 of Set 9 | houma
# Processing Record 39 of Set 9 | voznesenye
# Processing Record 40 of Set 9 | cacador
# Processing Record 41 of Set 9 | amapa
# Processing Record 42 of Set 9 | acajutla
# Processing Record 43 of Set 9 | baglung
# Processing Record 44 of Set 9 | jacqueville
# Processing Record 45 of Set 9 | buje
# Processing Record 46 of Set 9 | leh
# Processing Record 47 of Set 9 | traralgon
# Processing Record 48 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 9 | caravelas
# Processing Record 50 of Set 9 | sao jose da coroa grande
# Processing Record 1 of Set 10 | korla
# Processing Record 2 of Set 10 | manokwari
# Processing Record 3 of Set 10 | roma
# Processing Record 4 of Set 10 | madimba
# Processing Record 5 of Set 10 | pangkalanbuun
# Processing Record 6 of Set 10 | iquitos
# Processing Record 7 of Set 10 | chiredzi
# Processing Record 8 of Set 10 | nouadhibou
# Processing Record 9 of Set 10 | berlevag
# Processing Record 10 of Set 10 | palaia fokaia
# Processing Record 11 of Set 10 | atar
# Processing Record 12 of Set 10 | vestmannaeyjar
# Processing Record 13 of Set 10 | half moon bay
# Processing Record 14 of Set 10 | phetchaburi
# Processing Record 15 of Set 10 | rurrenabaque
# Processing Record 16 of Set 10 | sainte-maxime
# Processing Record 17 of Set 10 | jiexiu
# Processing Record 18 of Set 10 | bacolod
# Processing Record 19 of Set 10 | altamira
# Processing Record 20 of Set 10 | ozernovskiy
# Processing Record 21 of Set 10 | okakarara
# Processing Record 22 of Set 10 | ayan
# Processing Record 23 of Set 10 | sao francisco de assis
# Processing Record 24 of Set 10 | inirida
# Processing Record 25 of Set 10 | bekhtery
# Processing Record 26 of Set 10 | izhmorskiy
# Processing Record 27 of Set 10 | oriximina
# Processing Record 28 of Set 10 | orotukan
# Processing Record 29 of Set 10 | zafra
# Processing Record 30 of Set 10 | pout
# Processing Record 31 of Set 10 | coburg
# Processing Record 32 of Set 10 | kunri
# Processing Record 33 of Set 10 | winnemucca
# Processing Record 34 of Set 10 | sinnamary
# Processing Record 35 of Set 10 | acarau
# Processing Record 36 of Set 10 | zykovo
# Processing Record 37 of Set 10 | auki
# Processing Record 38 of Set 10 | victoria
# Processing Record 39 of Set 10 | tautira
# Processing Record 40 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 10 | canavieiras
# Processing Record 43 of Set 10 | dunedin
# Processing Record 44 of Set 10 | edd
# Processing Record 45 of Set 10 | annau
# Processing Record 46 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 47 of Set 10 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 48 of Set 10 | necochea
# Processing Record 49 of Set 10 | kuching
# Processing Record 50 of Set 10 | mujiayingzi
# Processing Record 1 of Set 11 | airai
# Processing Record 2 of Set 11 | port hedland
# Processing Record 3 of Set 11 | ojinaga
# Processing Record 4 of Set 11 | gornopravdinsk
# Processing Record 5 of Set 11 | vardo
# Processing Record 6 of Set 11 | ulaanbaatar
# Processing Record 7 of Set 11 | mana
# Processing Record 8 of Set 11 | bathsheba
# Processing Record 9 of Set 11 | mahon
# Processing Record 10 of Set 11 | luangwa
# Processing Record 11 of Set 11 | tabuk
# Processing Record 12 of Set 11 | marzuq
# Processing Record 13 of Set 11 | mayumba
# Processing Record 14 of Set 11 | thai nguyen
# Processing Record 15 of Set 11 | preobrazheniye
# Processing Record 16 of Set 11 | grindavik
# Processing Record 17 of Set 11 | umm kaddadah
# Processing Record 18 of Set 11 | itupiranga
# Processing Record 19 of Set 11 | sistranda
# Processing Record 20 of Set 11 | norrkoping
# Processing Record 21 of Set 11 | dubrovnik
# Processing Record 22 of Set 11 | westerland
# Processing Record 23 of Set 11 | spencer
# Processing Record 24 of Set 11 | burley
# Processing Record 25 of Set 11 | ilinskiy
# Processing Record 26 of Set 11 | temir
# Processing Record 27 of Set 11 | tamiahua
# Processing Record 28 of Set 11 | elizabeth city
# Processing Record 29 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 11 | terney
# Processing Record 31 of Set 11 | uthal
# Processing Record 32 of Set 11 | viedma
# Processing Record 33 of Set 11 | keskin
# Processing Record 34 of Set 11 | cawayan
# Processing Record 35 of Set 11 | antalaha
# Processing Record 36 of Set 11 | luanshya
# Processing Record 37 of Set 11 | wegorzewo
# Processing Record 38 of Set 11 | kajaani
# Processing Record 39 of Set 11 | portland
# Processing Record 40 of Set 11 | tual
# Processing Record 41 of Set 11 | sorong
# Processing Record 42 of Set 11 | angoche
# Processing Record 43 of Set 11 | quarai
# Processing Record 44 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 45 of Set 11 | maceio
# Processing Record 46 of Set 11 | obala
# Processing Record 47 of Set 11 | naushki
# Processing Record 48 of Set 11 | puerto padre
# Processing Record 49 of Set 11 | santa cecilia
# Processing Record 50 of Set 11 | henties bay
# Processing Record 1 of Set 12 | emerald
# Processing Record 2 of Set 12 | sinegorye
# Processing Record 3 of Set 12 | anloga
# Processing Record 4 of Set 12 | ust-kishert
# Processing Record 5 of Set 12 | aklavik
# Processing Record 6 of Set 12 | moron
# Processing Record 7 of Set 12 | limoeiro do ajuru
# Processing Record 8 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 9 of Set 12 | aborlan
# Processing Record 10 of Set 12 | atocha
# Processing Record 11 of Set 12 | montepuez
# Processing Record 12 of Set 12 | thyboron
# Processing Record 13 of Set 12 | alghero
# Processing Record 14 of Set 12 | vanino
# Processing Record 15 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 16 of Set 12 | tutoia
# Processing Record 17 of Set 12 | veraval
# Processing Record 18 of Set 12 | haines junction
# Processing Record 19 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 12 | beyneu
# Processing Record 21 of Set 12 | gat
# Processing Record 22 of Set 12 | olsztyn
# Processing Record 23 of Set 12 | kupang
# Processing Record 24 of Set 12 | terrace
# Processing Record 25 of Set 12 | ust-shonosha
# Processing Record 26 of Set 12 | jieshi
# Processing Record 27 of Set 12 | canmore
# Processing Record 28 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | mount gambier
# Processing Record 30 of Set 12 | pontes e lacerda
# Processing Record 31 of Set 12 | eyl
# Processing Record 32 of Set 12 | agropoli
# Processing Record 33 of Set 12 | zlitan
# Processing Record 34 of Set 12 | ust-nera
# Processing Record 35 of Set 12 | voh
# Processing Record 36 of Set 12 | nalut
# Processing Record 37 of Set 12 | williamsport
# Processing Record 38 of Set 12 | ambovombe
# Processing Record 39 of Set 12 | tombouctou
# Processing Record 40 of Set 12 | orebro
# Processing Record 41 of Set 12 | mindelo
# Processing Record 42 of Set 12 | olga
# Processing Record 43 of Set 12 | ati
# Processing Record 44 of Set 12 | sao joao da barra
# Processing Record 45 of Set 12 | alofi
# Processing Record 46 of Set 12 | vao
# Processing Record 47 of Set 12 | palana
# Processing Record 48 of Set 12 | foam lake
# Processing Record 49 of Set 12 | rona de sus
# Processing Record 50 of Set 12 | ranong
# Processing Record 1 of Set 13 | hadgaon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 77.67, 'lat': 19.5},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 79.61,
#   'feels_like': 86.45,
#   'temp_min': 79.61,
#   'temp_max': 79.61,
#   'pressure': 1003,
#   'humidity': 82,
#   'sea_level': 1003,
#   'grnd_level': 957},
#  'visibility': 10000,
#  'wind': {'speed': 4.83, 'deg': 144},
#  'clouds': {'all': 100},
#  'dt': 1596139842,
#  'sys': {'country': 'IN', 'sunrise': 1596155108, 'sunset': 1596201966},
#  'timezone': 19800,
#  'id': 1270554,
#  'name': 'Hadgāon',
#  'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv("city_data.csv")

# %%
city_data_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         lethem   3.38  -59.80     88.95        50          57        3.29
# 1      jamestown  42.10  -79.24     77.00        57          75        5.82
# 2  mar del plata -38.00  -57.56     53.01        57         100        6.93
# 3          manta  -0.95  -80.73     78.80        78          75        9.17
# 4     chokurdakh  70.63  147.92     44.29        83          73       11.12
#
#   Country        Date
# 0      GY  1596139879
# 1      US  1596139668
# 2      AR  1596139879
# 3      EC  1596139880
# 4      RU  1596139689

# %%
len(city_data_df)
# Out:
# 550

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
print(city_data_df['City'].where(city_data_df['Humidity'] > 100))
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 545    NaN
# 546    NaN
# 547    NaN
# 548    NaN
# 549    NaN
# Name: City, Length: 550, dtype: object

# %%
#  Get the indices of cities that have humidity over 100%.
city_data_df.agg({'Humidity':['mean', 'median', 'var', 'std', 'max', 'min']})
# Out:
#           Humidity
# mean     69.885455
# median   75.000000
# var     446.247329
# std      21.124567
# max     100.000000
# min       1.000000

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df["Lat"], 
            city_data_df["Max Temp"], c=city_data_df["Max Temp"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='hot', alpha=0.8, label="City")

plt.title('City Latitude vs. Max Temperature')
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.xlim([-80, 100])
plt.ylim([0, 120])
# Out:
# (0.0, 120.0)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df["Lat"], 
            city_data_df["Humidity"], c=city_data_df["Humidity"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='coolwarm', alpha=0.8, label="City")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs. Humidity')
plt.xlim([-80, 100])
plt.ylim([0, 120])
# Out:
# (0.0, 120.0)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df["Lat"], 
            city_data_df["Cloudiness"], c=city_data_df["Cloudiness"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='cool', alpha=0.8, label="City")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs. Cloudiness')
plt.xlim([-80, 100])
plt.ylim([0, 120])
# Out:
# (0.0, 120.0)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], 
            city_data_df["Wind Speed"], c=city_data_df["Wind Speed"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Latitude vs. Wind Speed')
plt.xlim([-80, 100])
plt.ylim([0, 120])
# Out:
# (0.0, 120.0)

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern (0 - 80) and Southern Hemisphere (-50 - 0) DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
regress_values = city_data_df["Lat"] * slope + intercept
print(regress_values)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
